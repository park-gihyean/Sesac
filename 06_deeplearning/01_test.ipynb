# %%
# 런타임 - 런타임 유형 관리 - none 기본 gpu(무료 할당량)

# %%
# 런타임 세션 관리 - 불필요한 연결은 해제

# %%
pwd
# Out:
# '/content'

# %%
# 파일 업로드, 다운로드 시 시간이 걸리게 된다.

# %%
# 직접 데이터를 올려서 작업해야 한다면, 구글 드라이브 쪽을 이용하는 것이 바람직 하다.

# %%
# 구글 드라이브 마운트

# %%
import pandas as pd

# %%
pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sesac_deeplearning/X_train.csv',encoding='cp949')
# 상대 경로로는 불가
# Out:
#               ID           직종          세부직종  \
# 0      SID100109  문화·예술·신문·방송  영상·음향·사진·카메라
# 1      SID100255  경영·기획·회계·사무      사무·총무·법무
# 2      SID100284        IT·게임  하드웨어설계·개발·관리
# 3      SID100315     영업·판매·TM          기술영업
# 4      SID100374     기술·과학·산업   기타 기술·과학·산업
# ...          ...          ...           ...
# 16565   SID99558     전문·교육·자격      금융·증권·투자
# 16566   SID99611  경영·기획·회계·사무         경리·회계
# 16567   SID99741  경영·기획·회계·사무      사무·총무·법무
# 16568   SID99756       통신·모바일     기타 통신·모바일
# 16569    SID9979     영업·판매·TM          해외영업
#
#                                                     직무태그     근무경력 근무형태  \
# 0                        취재기자, 편집 기사, 유아 사이트 기획, 시나리오 작성      0개월  NaN
# 1                                                    NaN  2년 11개월  정규직
# 2      하드웨어 , 무선통신 , MICOM , ASM , RF , CDMA , Firm W...      0개월  NaN
# 3                                                    반도체   1년 0개월  정규직
# 4                                                    기술직      0개월  NaN
# ...

# %%
import sys
sys.version
# Out:
# '3.8.16 (default, Dec  7 2022, 01:12:13) \n[GCC 7.5.0]'

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.9.2'

# %%
# 텐서플로우를 케라스를 통해서 편하게 쓸 수 있다.

# %%
# 버전 업 이후 호환성이 높아졌다.

# %%
# 케라스의 표현은 짧고 간결하다. (input, Model, Layer) 등과 같이 이름만으로 기능을 추측할 수 있다.

# %%
# 유연성, 모듈화 파이썬 기반

# %%
# 학습데이터 준비
# 문제를 해결하기 위한 모델을 정의
# 손실 함수, 옵티마이저 설정
# 모델을 학습시키고, 추론합니다.

# %%
# 가장 중요한 것은 명확한 문제 정의입니다.

# %%
# 선택한 모델이 주로 어떤 데이터에 적용되었는지,
# 모델이 얼마나 깊어야 하는 지?
# 옵티마이저, 손실 함수
# 우리의 실험 환경에 적합한가요?

# %%
# 데이터 불균형 문제
# 클래스 불균형

# 은행 거래 사기, 희귀 질병, 기계 불량

# 이상 탐지
# 모델 학습에 매우 부정적인 영향을 끼친다.

# 회귀 분류
# 이진 분류, 다중 분류
# 다중 레이블 분류

# 원핫 인코딩, 수치값이 크면 영향도가 크기 때문에, 원핫 인코딩을 사용한다.
# 딥러인은 가중치에 대한 것

# 하이퍼파라미터, 모델의 구조적
# 학습률, 배치 크기,에폭, 드롭아웃

# %%
# 텐서를 정의하자면 여러 형태를 가징 수 있는 넘파이 배열입니다.

# %%
a = tf.constant(2)
#상수 텐서

# %%
print(a)
# Out:
# tf.Tensor(2, shape=(), dtype=int32)

# %%
print(tf.rank(a))
#텐서의 랭크를 계산합니다.
# Out:
# tf.Tensor(0, shape=(), dtype=int32)

# %%
b = tf.constant([1,2])
print(tf.rank(b))
#1차원 배열의 랭크
# Out:
# tf.Tensor(1, shape=(), dtype=int32)

# %%
# 텐서플로우의 즉시 실행 모드

# %%
print(tf.add(a,b))
# subtrack, mutiply,
# Out:
# tf.Tensor([3 4], shape=(2,), dtype=int32)

# %%
# 가장 단순한 신경망, 퍼셉트론
